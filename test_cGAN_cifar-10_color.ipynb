# %%
import torch
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torchvision import utils
import torch.nn as nn
import torch.nn.functional as F
import os

import numpy as np

from PIL import Image
import glob
import time
import matplotlib.pyplot as plt
from torch.utils.data import TensorDataset

# %% [markdown]
# ### Data Loader
# #### - Loading Data (ImageNet, cifar-10, etc not MNIST)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
datamode = 1
if datamode == 0:
    datapath = './data/MNIST'
elif datamode ==1:
    datapath = './data/cifar10'

# %%
# Set Data path
# datapath = './data/cifar10'
os.makedirs(datapath, exist_ok=True)

# Pre-process
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5)),
])

# Laod MNIST
train_dataset = datasets.CIFAR10(datapath, train=True, download=True, transform=transform)
# Out:
# Files already downloaded and verified

# %%
img, label = train_dataset.data, train_dataset.targets
'''
print('img.shape:', img.shape)
print('label.shape:', label.shape)

# Make it to 4D Tensor
# 기존 : (#Batch) x (height) x (width) -> (#Batch) x (#channel) x (height) x(width)
if len(img.shape) == 3:
    img = img.unsqueeze(1)
print('Unsqueezed img.shape:', img.shape)

# Visualize
img_grid = utils.make_grid(img[:40], ncol=8, padding=2)
def show(img):
    img = img.numpy() # Tensor -> numpy array
    img = img.transpose([1,2,0]) # C x H x W -> H x W x C
    plt.imshow(img, interpolation='nearest')
show(img_grid)
'''
# Out:
# "\nprint('img.shape:', img.shape)\nprint('label.shape:', label.shape)\n\n# Make it to 4D Tensor\n# 기존 : (#Batch) x (height) x (width) -> (#Batch) x (#channel) x (height) x(width)\nif len(img.shape) == 3:\n    img = img.unsqueeze(1)\nprint('Unsqueezed img.shape:', img.shape)\n\n# Visualize\nimg_grid = utils.make_grid(img[:40], ncol=8, padding=2)\ndef show(img):\n    img = img.numpy() # Tensor -> numpy array\n    img = img.transpose([1,2,0]) # C x H x W -> H x W x C\n    plt.imshow(img, interpolation='nearest')\nshow(img_grid)\n"

# %%
batch_size = 64

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

test_dataset = datasets.CIFAR10(datapath, train=False,
                                       download=True, transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified

# %%
import matplotlib.pyplot as plt
import numpy as np
import torchvision

# 이미지를 보여주기 위한 함수

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# 학습용 이미지를 무작위로 가져오기
dataiter = iter(test_loader)
images, labels = next(dataiter)
#print(images[0].shape)
#plt.figure(figsize = (3,3))
#plt.imshow(np.transpose(images[0].numpy(),(1,2,0)))
# 이미지 보여주기
imshow(torchvision.utils.make_grid(images))
# 정답(label) 출력
print(' '.join(f'{classes[labels[j]]:5s}' for j in range(batch_size)))
# Out:
# cat   ship  ship  plane frog  frog  car   frog  cat   car   plane truck dog   horse truck ship  dog   horse ship  frog  horse plane deer  truck dog   bird  deer  plane truck frog  frog  dog   deer  dog   truck bird  deer  car   truck dog   deer  frog  dog   frog  plane truck cat   truck horse frog  truck ship  plane cat   ship  ship  horse horse deer  frog  horse cat   frog  cat

# %%
#train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
print(len(train_loader))
# Out:
# 782

# %%
# set parameters
params = {
    'num_classes':10,
    'nz':100,
    'input_size':(3,32,32)
}

# %%
class Generator(nn.Module):
    
    def __init__(self, params):
        super().__init__()
        self.num_classes = params['num_classes']
        self.nz = params['nz'] # 노이즈 수
        self.input_size = params['input_size'] # (1,28,28
        
        # Noise와 label을 결합하는 용도인 label embedding matrix를 생성
        self.label_emb = nn.Embedding(self.num_classes, self.num_classes)
        
        # Generator
        self.gen = nn.Sequential(
            nn.Linear(self.nz + self.num_classes, 128),
            nn.LeakyReLU(0.2),
            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.2),
            nn.Linear(256,512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(0.2),
            nn.Linear(512,1024),
            nn.BatchNorm1d(1024),
            nn.LeakyReLU(0.2),
            nn.Linear(1024,int(np.prod(self.input_size))),
            nn.Tanh()
        )
        
    def forward(self, noise, labels):
        # noise와 label의 결합
        gen_input = torch.cat((self.label_emb(labels), noise), -1)
        x = self.gen(gen_input)
        x = x.view(x.size(0), *self.input_size)
        return x
    
# check
x = torch.randn(16,100,device=device) # 노이즈
label = torch.randint(0,10,(16,),device=device) # 레이블
model_gen = Generator(params).to(device)
out_gen = model_gen(x,label) # 가짜 이미지 생성
print(out_gen.shape)
# Out:
# torch.Size([16, 3, 32, 32])

# %%
class Discriminator(nn.Module):
    
     def __init__(self, params):
        super().__init__()
        self.input_size = params['input_size']
        self.num_classes = params['num_classes']
        self.label_embedding = nn.Embedding(self.num_classes, self.num_classes)
        self.dis = nn.Sequential(
            nn.Linear(self.num_classes+int(np.prod(self.input_size)),512),
            nn.LeakyReLU(0.2),
            nn.Linear(512,512),
            nn.Dropout(0.4),
            nn.LeakyReLU(0.2),
            nn.Linear(512,512),
            nn.Dropout(0.4),
            nn.LeakyReLU(0.2),
            nn.Linear(512,1),
            nn.Sigmoid()
        )
        
     def forward(self, img, labels):
        # 이미지와 label 결합
        dis_input = torch.cat((img.view(img.size(0),-1),self.label_embedding(labels)),-1)
        x = self.dis(dis_input)
        return x
    
# check
x = torch.randn(16,3,32,32,device=device)
label = torch.randint(0,10,(16,), device=device)
model_dis = Discriminator(params).to(device)
out_dis = model_dis(x,label)
print(out_dis.shape)
# Out:
# torch.Size([16, 1])

# %%
# 가중치 초기화
def initialize_weights(model):
    classname = model.__class__.__name__
    # fc layer
    if classname.find('Linear') != -1:
        nn.init.normal_(model.weight.data, 0.0, 0.02)
        nn.init.constant_(model.bias.data, 0)
    # batchnorm
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(model.weight.data, 1.0, 0.02)
        nn.init.constant_(model.bias.data, 0)

# 가중치 초기화 적용
model_gen.apply(initialize_weights);
model_dis.apply(initialize_weights);

# %%
# 손실 함수
loss_func = nn.BCELoss() 

from torch import optim

lr = 2e-4
beta1 = 0.5
beta2 = 0.999

# optimization
opt_dis = optim.Adam(model_dis.parameters(), lr=lr, betas=(beta1,beta2)) # Discrminator
opt_gen = optim.Adam(model_gen.parameters(), lr=lr, betas=(beta1,beta2)) # Generator

# 학습 파라미터
nz = params['nz'] # Noise vector initialize
num_epochs = 200

loss_history={'gen':[],
              'dis':[]}

# %%
# Train
batch_count = 0
start_time = time.time()
model_dis.train()
model_gen.train()

for epoch in range(num_epochs):
    for xb, yb in train_loader:
        ba_si = xb.shape[0]
        
        xb = xb.to(device)
        yb = yb.to(device)
        yb_real = torch.Tensor(ba_si, 1).fill_(1.0).to(device) # real_label
        yb_fake = torch.Tensor(ba_si, 1).fill_(0.0).to(device) # fake_label
        
        # Genetator
        model_gen.zero_grad()
        noise = torch.randn(ba_si,100).to(device) # 노이즈 생성
        gen_label = torch.randint(0,10,(ba_si,)).to(device) # label 생성

         # 가짜 이미지 생성
        out_gen = model_gen(noise, gen_label)

        # 가짜 이미지 판별
        out_dis = model_dis(out_gen, gen_label)

        loss_gen = loss_func(out_dis, yb_real)
        loss_gen.backward()
        opt_gen.step()

        # Discriminator
        model_dis.zero_grad()
        
        # 진짜 이미지 판별
        out_dis = model_dis(xb, yb)
        loss_real = loss_func(out_dis, yb_real)

        # 가짜 이미지 판별
        out_dis = model_dis(out_gen.detach(),gen_label)
        loss_fake = loss_func(out_dis,yb_fake)

        loss_dis = (loss_real + loss_fake) / 2
        loss_dis.backward()
        opt_dis.step()

        loss_history['gen'].append(loss_gen.item())
        loss_history['dis'].append(loss_dis.item())

        batch_count += 1
        if batch_count % 1000 == 0:
            print('Epoch: %.0f, G_Loss: %.6f, D_Loss: %.6f, time: %.2f min' %(epoch, loss_gen.item(), loss_dis.item(), (time.time()-start_time)/60))
# Out:
# Epoch: 1, G_Loss: 1.623886, D_Loss: 0.288013, time: 0.21 min
# Epoch: 2, G_Loss: 1.753747, D_Loss: 0.443248, time: 0.41 min
# Epoch: 3, G_Loss: 1.154745, D_Loss: 0.494741, time: 0.63 min
# Epoch: 5, G_Loss: 2.337884, D_Loss: 0.347728, time: 0.83 min
# Epoch: 6, G_Loss: 1.286582, D_Loss: 0.532960, time: 1.04 min
# Epoch: 7, G_Loss: 0.918267, D_Loss: 0.666556, time: 1.25 min
# Epoch: 8, G_Loss: 2.129616, D_Loss: 0.291114, time: 1.46 min
# Epoch: 10, G_Loss: 11.379206, D_Loss: 0.302114, time: 1.66 min
# Epoch: 11, G_Loss: 2.346772, D_Loss: 0.234337, time: 1.87 min
# Epoch: 12, G_Loss: 5.170272, D_Loss: 0.412012, time: 2.07 min
# Epoch: 14, G_Loss: 1.017853, D_Loss: 0.622919, time: 2.28 min
# Epoch: 15, G_Loss: 1.442586, D_Loss: 0.479106, time: 2.48 min
# Epoch: 16, G_Loss: 1.171751, D_Loss: 0.573942, time: 2.69 min
# Epoch: 17, G_Loss: 1.013713, D_Loss: 0.610343, time: 2.89 min
# Epoch: 19, G_Loss: 1.609575, D_Loss: 0.416327, time: 3.10 min
# Epoch: 20, G_Loss: 1.063683, D_Loss: 0.451287, time: 3.30 min
# Epoch: 21, G_Loss: 1.001413, D_Loss: 0.584453, time: 3.50 min
# Epoch: 23, G_Loss: 0.822675, D_Loss: 0.662030, time: 3.70 min
# Epoch: 24, G_Loss: 0.871313, D_Loss: 0.616383, time: 3.90 min
# Epoch: 25, G_Loss: 1.059571, D_Loss: 0.539702, time: 4.10 min
# Epoch: 26, G_Loss: 1.208843, D_Loss: 0.443267, time: 4.31 min
# Epoch: 28, G_Loss: 0.945809, D_Loss: 0.539408, time: 4.52 min
# Epoch: 29, G_Loss: 0.862395, D_Loss: 0.642055, time: 4.73 min
# Epoch: 30, G_Loss: 0.906013, D_Loss: 0.595889, time: 4.93 min
# Epoch: 31, G_Loss: 1.007177, D_Loss: 0.610108, time: 5.14 min
# Epoch: 33, G_Loss: 0.843544, D_Loss: 0.663887, time: 5.35 min
# Epoch: 34, G_Loss: 0.868294, D_Loss: 0.588832, time: 5.55 min
# Epoch: 35, G_Loss: 0.901240, D_Loss: 0.647368, time: 5.75 min
# Epoch: 37, G_Loss: 0.905560, D_Loss: 0.528296, time: 5.96 min
# Epoch: 38, G_Loss: 0.933416, D_Loss: 0.566580, time: 6.16 min
# Epoch: 39, G_Loss: 0.922408, D_Loss: 0.654932, time: 6.36 min
# Epoch: 40, G_Loss: 0.732343, D_Loss: 0.580455, time: 6.57 min
# Epoch: 42, G_Loss: 0.894025, D_Loss: 0.609333, time: 6.77 min
# Epoch: 43, G_Loss: 1.115464, D_Loss: 0.544982, time: 6.97 min
# Epoch: 44, G_Loss: 0.861305, D_Loss: 0.719536, time: 7.17 min
# Epoch: 46, G_Loss: 0.884087, D_Loss: 0.604322, time: 7.38 min
# Epoch: 47, G_Loss: 0.911449, D_Loss: 0.525117, time: 7.58 min
# Epoch: 48, G_Loss: 0.954183, D_Loss: 0.542073, time: 7.79 min
# Epoch: 49, G_Loss: 0.976773, D_Loss: 0.578999, time: 7.99 min
# Epoch: 51, G_Loss: 0.943557, D_Loss: 0.648125, time: 8.19 min
# Epoch: 52, G_Loss: 0.935321, D_Loss: 0.625268, time: 8.40 min
# Epoch: 53, G_Loss: 1.060024, D_Loss: 0.654490, time: 8.60 min
# Epoch: 54, G_Loss: 0.817488, D_Loss: 0.687637, time: 8.81 min
# Epoch: 56, G_Loss: 0.814844, D_Loss: 0.562469, time: 9.02 min
# Epoch: 57, G_Loss: 1.089424, D_Loss: 0.486351, time: 9.22 min
# Epoch: 58, G_Loss: 1.021418, D_Loss: 0.488737, time: 9.42 min
# Epoch: 60, G_Loss: 1.012193, D_Loss: 0.590385, time: 9.62 min
# Epoch: 61, G_Loss: 1.037920, D_Loss: 0.581679, time: 9.82 min
# Epoch: 62, G_Loss: 1.177358, D_Loss: 0.532078, time: 10.02 min
# Epoch: 63, G_Loss: 0.907736, D_Loss: 0.572713, time: 10.22 min
# Epoch: 65, G_Loss: 1.178270, D_Loss: 0.564902, time: 10.43 min
# Epoch: 66, G_Loss: 0.946307, D_Loss: 0.647358, time: 10.63 min
# Epoch: 67, G_Loss: 1.129704, D_Loss: 0.545985, time: 10.83 min
# Epoch: 69, G_Loss: 1.013075, D_Loss: 0.585047, time: 11.04 min
# Epoch: 70, G_Loss: 1.041062, D_Loss: 0.613298, time: 11.24 min
# Epoch: 71, G_Loss: 1.361407, D_Loss: 0.547565, time: 11.44 min
# Epoch: 72, G_Loss: 1.004047, D_Loss: 0.595610, time: 11.64 min
# Epoch: 74, G_Loss: 0.932378, D_Loss: 0.689790, time: 11.85 min
# Epoch: 75, G_Loss: 1.050670, D_Loss: 0.636589, time: 12.05 min
# Epoch: 76, G_Loss: 1.177554, D_Loss: 0.584205, time: 12.25 min
# Epoch: 78, G_Loss: 0.990209, D_Loss: 0.564395, time: 12.46 min
# Epoch: 79, G_Loss: 0.841394, D_Loss: 0.656592, time: 12.66 min
# Epoch: 80, G_Loss: 1.029207, D_Loss: 0.591917, time: 12.86 min
# Epoch: 81, G_Loss: 1.181680, D_Loss: 0.646693, time: 13.06 min
# Epoch: 83, G_Loss: 1.514498, D_Loss: 0.460495, time: 13.27 min
# Epoch: 84, G_Loss: 0.939182, D_Loss: 0.588962, time: 13.47 min
# Epoch: 85, G_Loss: 0.885296, D_Loss: 0.585226, time: 13.67 min
# Epoch: 86, G_Loss: 1.104601, D_Loss: 0.583870, time: 13.88 min
# Epoch: 88, G_Loss: 1.570563, D_Loss: 0.361203, time: 14.08 min
# Epoch: 89, G_Loss: 0.999440, D_Loss: 0.567132, time: 14.29 min
# Epoch: 90, G_Loss: 1.374372, D_Loss: 0.500042, time: 14.49 min
# Epoch: 92, G_Loss: 1.436913, D_Loss: 0.486284, time: 14.70 min
# Epoch: 93, G_Loss: 1.268673, D_Loss: 0.508409, time: 14.91 min
# Epoch: 94, G_Loss: 1.025367, D_Loss: 0.466060, time: 15.12 min
# Epoch: 95, G_Loss: 0.870317, D_Loss: 0.644247, time: 15.32 min
# Epoch: 97, G_Loss: 0.911343, D_Loss: 0.628914, time: 15.52 min
# Epoch: 98, G_Loss: 1.362294, D_Loss: 0.541227, time: 15.72 min
# Epoch: 99, G_Loss: 0.905222, D_Loss: 0.531648, time: 15.93 min
# Epoch: 101, G_Loss: 0.952924, D_Loss: 0.595973, time: 16.13 min
# Epoch: 102, G_Loss: 1.008500, D_Loss: 0.617459, time: 16.35 min
# Epoch: 103, G_Loss: 1.044932, D_Loss: 0.547264, time: 16.55 min
# Epoch: 104, G_Loss: 0.955489, D_Loss: 0.703357, time: 16.76 min
# Epoch: 106, G_Loss: 1.254450, D_Loss: 0.577584, time: 16.96 min
# Epoch: 107, G_Loss: 1.116626, D_Loss: 0.572638, time: 17.16 min
# Epoch: 108, G_Loss: 1.226511, D_Loss: 0.608259, time: 17.36 min
# Epoch: 109, G_Loss: 0.990325, D_Loss: 0.539387, time: 17.57 min
# Epoch: 111, G_Loss: 0.999251, D_Loss: 0.614445, time: 17.77 min
# Epoch: 112, G_Loss: 1.132101, D_Loss: 0.614561, time: 17.98 min
# Epoch: 113, G_Loss: 1.181248, D_Loss: 0.555852, time: 18.18 min
# Epoch: 115, G_Loss: 0.973324, D_Loss: 0.589812, time: 18.40 min
# Epoch: 116, G_Loss: 1.334803, D_Loss: 0.514316, time: 18.60 min
# Epoch: 117, G_Loss: 0.965828, D_Loss: 0.639692, time: 18.80 min
# Epoch: 118, G_Loss: 0.947020, D_Loss: 0.681190, time: 19.01 min
# Epoch: 120, G_Loss: 1.320269, D_Loss: 0.609066, time: 19.22 min
# Epoch: 121, G_Loss: 1.614747, D_Loss: 0.500810, time: 19.42 min
# Epoch: 122, G_Loss: 1.241929, D_Loss: 0.646232, time: 19.62 min
# Epoch: 124, G_Loss: 1.110480, D_Loss: 0.592753, time: 19.82 min
# Epoch: 125, G_Loss: 1.298482, D_Loss: 0.415592, time: 20.02 min
# Epoch: 126, G_Loss: 0.967562, D_Loss: 0.600050, time: 20.22 min
# Epoch: 127, G_Loss: 1.201749, D_Loss: 0.540132, time: 20.42 min
# Epoch: 129, G_Loss: 1.009490, D_Loss: 0.557662, time: 20.62 min
# Epoch: 130, G_Loss: 1.277515, D_Loss: 0.525445, time: 20.82 min
# Epoch: 131, G_Loss: 0.932721, D_Loss: 0.638132, time: 21.03 min
# Epoch: 132, G_Loss: 1.021369, D_Loss: 0.544173, time: 21.22 min
# Epoch: 134, G_Loss: 1.334743, D_Loss: 0.544938, time: 21.44 min
# Epoch: 135, G_Loss: 1.097195, D_Loss: 0.496531, time: 21.65 min
# Epoch: 136, G_Loss: 1.197465, D_Loss: 0.553127, time: 21.85 min
# Epoch: 138, G_Loss: 1.146294, D_Loss: 0.549084, time: 22.06 min
# Epoch: 139, G_Loss: 0.748911, D_Loss: 0.701596, time: 22.26 min
# Epoch: 140, G_Loss: 1.032364, D_Loss: 0.560056, time: 22.47 min
# Epoch: 141, G_Loss: 1.549716, D_Loss: 0.404865, time: 22.67 min
# Epoch: 143, G_Loss: 1.159666, D_Loss: 0.562879, time: 22.88 min
# Epoch: 144, G_Loss: 1.046070, D_Loss: 0.713823, time: 23.08 min
# Epoch: 145, G_Loss: 1.198169, D_Loss: 0.500124, time: 23.28 min
# Epoch: 147, G_Loss: 0.994778, D_Loss: 0.557979, time: 23.49 min
# Epoch: 148, G_Loss: 2.440629, D_Loss: 0.378969, time: 23.69 min
# Epoch: 149, G_Loss: 0.992621, D_Loss: 0.650077, time: 23.89 min
# Epoch: 150, G_Loss: 0.906283, D_Loss: 0.603867, time: 24.09 min
# Epoch: 152, G_Loss: 1.075753, D_Loss: 0.543836, time: 24.29 min
# Epoch: 153, G_Loss: 1.091918, D_Loss: 0.560086, time: 24.49 min
# Epoch: 154, G_Loss: 1.477297, D_Loss: 0.496215, time: 24.70 min
# Epoch: 156, G_Loss: 1.240415, D_Loss: 0.507933, time: 24.92 min
# Epoch: 157, G_Loss: 1.094557, D_Loss: 0.519037, time: 25.11 min
# Epoch: 158, G_Loss: 0.718344, D_Loss: 0.746592, time: 25.31 min
# Epoch: 159, G_Loss: 1.148579, D_Loss: 0.529854, time: 25.52 min
# Epoch: 161, G_Loss: 1.147687, D_Loss: 0.565613, time: 25.72 min
# Epoch: 162, G_Loss: 0.919506, D_Loss: 0.615850, time: 25.92 min
# Epoch: 163, G_Loss: 1.383582, D_Loss: 0.576038, time: 26.13 min
# Epoch: 164, G_Loss: 1.259493, D_Loss: 0.600984, time: 26.33 min
# Epoch: 166, G_Loss: 1.276897, D_Loss: 0.526256, time: 26.53 min
# Epoch: 167, G_Loss: 1.341047, D_Loss: 0.521347, time: 26.73 min
# Epoch: 168, G_Loss: 1.195755, D_Loss: 0.579157, time: 26.94 min
# Epoch: 170, G_Loss: 1.207080, D_Loss: 0.562174, time: 27.14 min
# Epoch: 171, G_Loss: 1.156430, D_Loss: 0.569359, time: 27.34 min
# Epoch: 172, G_Loss: 1.211758, D_Loss: 0.584847, time: 27.55 min
# Epoch: 173, G_Loss: 1.121924, D_Loss: 0.541012, time: 27.75 min
# Epoch: 175, G_Loss: 1.061354, D_Loss: 0.605960, time: 27.96 min
# Epoch: 176, G_Loss: 0.916435, D_Loss: 0.625741, time: 28.18 min
# Epoch: 177, G_Loss: 1.537371, D_Loss: 0.546218, time: 28.39 min
# Epoch: 179, G_Loss: 1.068920, D_Loss: 0.671771, time: 28.59 min
# Epoch: 180, G_Loss: 1.292593, D_Loss: 0.494293, time: 28.80 min
# Epoch: 181, G_Loss: 1.211025, D_Loss: 0.499923, time: 29.00 min
# Epoch: 182, G_Loss: 0.903206, D_Loss: 0.593224, time: 29.20 min
# Epoch: 184, G_Loss: 1.241092, D_Loss: 0.494438, time: 29.41 min
# Epoch: 185, G_Loss: 1.010449, D_Loss: 0.564756, time: 29.61 min
# Epoch: 186, G_Loss: 1.131490, D_Loss: 0.581121, time: 29.81 min
# Epoch: 187, G_Loss: 1.064463, D_Loss: 0.572881, time: 30.01 min
# Epoch: 189, G_Loss: 1.673804, D_Loss: 0.488263, time: 30.22 min
# Epoch: 190, G_Loss: 1.729253, D_Loss: 0.451088, time: 30.42 min
# Epoch: 191, G_Loss: 1.644594, D_Loss: 0.499662, time: 30.62 min
# Epoch: 193, G_Loss: 1.797644, D_Loss: 0.495056, time: 30.83 min
# Epoch: 194, G_Loss: 1.480257, D_Loss: 0.484762, time: 31.03 min
# Epoch: 195, G_Loss: 1.365862, D_Loss: 0.435978, time: 31.25 min
# Epoch: 196, G_Loss: 1.456431, D_Loss: 0.450145, time: 31.46 min
# Epoch: 198, G_Loss: 1.212259, D_Loss: 0.572949, time: 31.67 min
# Epoch: 199, G_Loss: 1.101522, D_Loss: 0.616769, time: 31.87 min

# %%
# plot loss history
plt.figure(figsize=(10,5))
plt.title('Loss Progress')
plt.plot(loss_history['gen'], label='Gen. Loss')
plt.plot(loss_history['dis'], label='Dis. Loss')
plt.xlabel('batch count')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
path2models = './models/'
os.makedirs(path2models, exist_ok=True)
path2weights_gen = os.path.join(path2models, 'weights_gen.pt')
path2weights_dis = os.path.join(path2models, 'weights_dis.pt')

torch.save(model_gen.state_dict(), path2weights_gen)
torch.save(model_dis.state_dict(), path2weights_dis)

# %%
# 가중치 불러오기
weights = torch.load(path2weights_gen)
model_gen.load_state_dict(weights)

# evalutaion mode
model_gen.eval()

# fake image 생성
with torch.no_grad():
    fig = plt.figure(figsize=(8,8))
    cols, rows = 4, 4 # row와 col 갯수
    for i in range(rows * cols):
        fixed_noise = torch.randn(16, 100, device=device)
        label = torch.randint(0,9,(16,), device=device)
        img_fake = model_gen(fixed_noise, label).detach().cpu()
        fig.add_subplot(rows, cols, i+1)
        plt.title(label[i].item())
        plt.axis('off')
        img_fake_tmp = img_fake[i].swapaxes(0,1)
        img_fake_print = img_fake_tmp.swapaxes(1,2)
        plt.imshow(img_fake_print.squeeze())
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_fake[i]
# Out:
# tensor([[[ 0.4344,  0.5878,  0.6131,  ...,  0.5059,  0.6387,  0.7053],
#          [ 0.8382,  0.4964,  0.7254,  ...,  0.7543,  0.7404,  0.6840],
#          [ 0.5166,  0.6249,  0.7109,  ...,  0.4000,  0.7536,  0.5736],
#          ...,
#          [-0.4491, -0.0290, -0.6514,  ...,  0.1949, -0.1100, -0.3507],
#          [-0.3830,  0.0431, -0.0579,  ...,  0.0161,  0.3141,  0.0239],
#          [-0.1634, -0.2413, -0.2351,  ...,  0.0969,  0.0122, -0.2949]],
#
#         [[ 0.5915,  0.5624,  0.6372,  ...,  0.6589,  0.2783,  0.5809],
#          [ 0.6112,  0.8146,  0.5616,  ...,  0.4476,  0.6099,  0.4369],
#          [ 0.5124,  0.7050,  0.4199,  ...,  0.5069,  0.4645,  0.6813],
#          ...,
#          [-0.2712, -0.4528, -0.3670,  ..., -0.5877, -0.3161,  0.0649],
#          [-0.3264,  0.0192, -0.1420,  ..., -0.2105, -0.5023, -0.2503],
#          [-0.5072, -0.4530, -0.3291,  ..., -0.2750, -0.4683, -0.5119]],
#
#         [[ 0.6306,  0.5223,  0.4893,  ...,  0.1437,  0.4649,  0.6383],
#          [ 0.1418,  0.4855,  0.5066,  ...,  0.1274,  0.3001,  0.5705],
#          [ 0.6201,  0.4599,  0.6099,  ...,  0.1508,  0.5265,  0.5020],
#          ...,
#          [-0.1345,  0.1192, -0.4993,  ..., -0.4180, -0.1887, -0.0185],
#          [-0.4314, -0.5151, -0.1772,  ..., -0.4572, -0.0103, -0.5195],
#          [-0.3962, -0.4765, -0.5619,  ...,  0.0198, -0.2145, -0.2855]]])

# %%
# 가중치 불러오기
weights = torch.load(path2weights_gen)
model_gen.load_state_dict(weights)

# evalutaion mode
model_gen.eval()

# fake image 생성
with torch.no_grad():
    fig = plt.figure(figsize=(12,12))
    cols, rows = 4, 4 # row와 col 갯수
    for i in range(rows * cols):
        fixed_noise = torch.randn(16, 100, device=device)
        label = torch.randint(0,1,(16,), device=device)
        img_fake = model_gen(fixed_noise, label).detach().cpu()
        fig.add_subplot(rows, cols, i+1)
        plt.title(label[i].item())
        plt.axis('off')
        img_fake_tmp = img_fake[i].swapaxes(0,1)
        img_fake_print = img_fake_tmp.swapaxes(1,2)
        plt.imshow(img_fake_print.squeeze())
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 가중치 불러오기
weights = torch.load(path2weights_gen)
model_gen.load_state_dict(weights)

# evalutaion mode
model_gen.eval()

# fake image 생성
with torch.no_grad():
    fig = plt.figure(figsize=(12,12))
    cols, rows = 4, 4 # row와 col 갯수
    for i in range(rows * cols):
        fixed_noise = torch.randn(16, 100, device=device)
        label = torch.randint(1,2,(16,), device=device)
        img_fake = model_gen(fixed_noise, label).detach().cpu()
        fig.add_subplot(rows, cols, i+1)
        plt.title(label[i].item())
        plt.axis('off')
        img_fake_tmp = img_fake[i].swapaxes(0,1)
        img_fake_print = img_fake_tmp.swapaxes(1,2)
        plt.imshow(img_fake_print.squeeze())
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 가중치 불러오기
weights = torch.load(path2weights_gen)
model_gen.load_state_dict(weights)

# evalutaion mode
model_gen.eval()

# fake image 생성
with torch.no_grad():
    fig = plt.figure(figsize=(12,12))
    cols, rows = 4, 4 # row와 col 갯수
    for i in range(rows * cols):
        fixed_noise = torch.randn(16, 100, device=device)
        label = torch.randint(9,10,(16,), device=device)
        img_fake = model_gen(fixed_noise, label).detach().cpu()
        fig.add_subplot(rows, cols, i+1)
        plt.title(label[i].item())
        plt.axis('off')
        img_fake_tmp = img_fake[i].swapaxes(0,1)
        img_fake_print = img_fake_tmp.swapaxes(1,2)
        plt.imshow(img_fake_print.squeeze())
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
'''
0 gyaetongdo
1 pyeongmyundo
2 goosungdo
3 gigibaechido
4 Legends
5 layout
6 cable_wiring_diagram
7 Seonbunjang
8 poseoldo
9 sangsaedo
10 gaehwangdo
11 wiichido
12 domyunmokcha
13 gujomooldo
14 ganji
15 jickseondo
'''
